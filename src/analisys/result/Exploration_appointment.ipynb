# %%
import sys
sys.path.append('../../')
from utils.connection import postgres_connection
import pandas as pd

# %%
query = """
select * from healthcare.refined.appointments a 
"""

df = pd.read_sql(query, con=postgres_connection())

df
# Out:
#      appointment_id  patient_id appointment_date appointment_type  \
# 0                 1          37       2023-02-25          Checkup
# 1                 2          36       2023-03-10        Emergency
# 2                 3          46       2023-04-02          Checkup
# 3                 4           1       2023-01-16     Consultation
# 4                 5          42       2023-03-24        Emergency
# ..              ...         ...              ...              ...
# 415             101          51       2022-12-15          Checkup
# 416             102          52       2023-01-20     Consultation
# 417             103          53       2023-01-10        Emergency
# 418             104          54       2023-02-05          Checkup
# 419             105          55       2022-12-25     Consultation
#
#      provider_id             date_insertion day_of_week  \
# 0              4 2025-05-20 22:26:25.402163    Saturday
# 1              7 2025-05-20 22:26:25.402163      Friday
# 2              3 2025-05-20 22:26:25.402163      Sunday
# 3              6 2025-05-20 22:26:25.402163      Monday
# 4              4 2025-05-20 22:26:25.402163      Friday
# ..           ...                        ...         ...
# 415            4 2025-05-20 22:32:43.758023    Thursday
# 416            2 2025-05-20 22:32:43.758023      Friday
# 417            7 2025-05-20 22:32:43.758023     Tuesday
# 418            5 2025-05-20 22:32:43.758023      Sunday
# 419            3 2025-05-20 22:32:43.758023      Sunday
#
#      time_since_last_appointment
# 0                            815
# 1                            802
# 2                            779
# 3                            855
# 4                            788
# ..                           ...
# 415                          887
# 416                          851
# 417                          861
# 418                          835
# 419                          877
#
# [420 rows x 8 columns]
